# %%
print("Hello world")
# Out:
# Hello world

# %%
import pandas as pd

# %%
df = pd.read_csv('laptopPrice.csv')

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# ...

# %%
df.tail()
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd   hdd       os  os_bit graphic_card_gb      weight     warranty  \
# 818  1024 GB  0 GB  Windows  64-bit            0 GB      Casual       1 year
# 819  1024 GB  0 GB  Windows  64-bit            0 GB      Casual       1 year
# 820  1024 GB  0 GB  Windows  64-bit            4 GB      Casual       1 year
# 821  1024 GB  0 GB  Windows  64-bit            4 GB      Casual       1 year
# 822   512 GB  0 GB      DOS  64-bit            0 GB  ThinNlight  No warranty
#
# ...

# %%
df[["brand","Price"]]
# Out:
#       brand   Price
# 0      ASUS   34649
# 1    Lenovo   38999
# 2    Lenovo   39999
# 3      ASUS   69990
# 4      ASUS   26990
# ..      ...     ...
# 818    ASUS  135990
# 819    ASUS  144990
# 820    ASUS  149990
# 821    ASUS  142990
# 822  Lenovo   57490
#
# [823 rows x 2 columns]

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
asus = df[df['brand'] == 'ASUS']

# %%
asus.shape
# Out:
# (249, 19)

# %%
# brand == asus 
# ram == 8 gb 
# 64-bit


asus = df[(df['brand']=='ASUS')&(df['ram_gb']=="8 GB")&(df['os_bit']=="64-bit")]

# %%
# asus.to_csv("asus_laptop.csv")

# %%
# df.loc[0:20,['brand','Price']]
asus.loc[20:40,['processor_brand','Price']]
# Out:
#    processor_brand  Price
# 27           Intel  33980
# 32           Intel  37990
# 33           Intel  37890
# 37           Intel  45990

# %%
df.isnull().sum()
# Out:
# brand                 0
# processor_brand       0
# processor_name        0
# processor_gnrtn       0
# ram_gb                0
# ram_type              0
# ssd                   0
# hdd                   0
# os                    0
# os_bit                0
# graphic_card_gb       0
# weight                0
# warranty              0
# Touchscreen           0
# msoffice              0
# Price                26
# rating                0
# Number of Ratings     0
# Number of Reviews     0
# dtype: int64

# %%
# 1. delete record   
# 2. filling records


#25000
# mean & median (average)

# %%
df['Price'].fillna(77879,inplace=True)

# %%
df['Price']
# Out:
# 0       77879.0
# 1       77879.0
# 2       77879.0
# 3       77879.0
# 4       77879.0
#          ...
# 818    135990.0
# 819    144990.0
# 820    149990.0
# 821    142990.0
# 822     57490.0
# Name: Price, Length: 823, dtype: float64

# %%
df.isnull().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
df['processor_brand'].value_counts()
# Out:
# processor_brand
# Intel    610
# AMD      189
# M1        24
# Name: count, dtype: int64

# %%
df[df['processor_brand']=="M1"]
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 599  APPLE              M1             M1            10th   8 GB     DDR4
# 600  APPLE              M1             M1            10th   8 GB     DDR4
# 601  APPLE              M1             M1            10th  16 GB     DDR4
# 602  APPLE              M1             M1            10th   8 GB     DDR4
# 603  APPLE              M1             M1            10th  16 GB     DDR4
# 604  APPLE              M1             M1            10th  16 GB     DDR4
# 605  APPLE              M1             M1            10th   8 GB     DDR4
# 606  APPLE              M1             M1            10th  16 GB     DDR4
# 607  APPLE              M1             M1            10th   8 GB     DDR4
# 608  APPLE              M1             M1            10th   8 GB     DDR4
# 609  APPLE              M1             M1            10th   8 GB     DDR4
# 610  APPLE              M1             M1            10th   8 GB     DDR4
# ...

# %%
df['ram_gb'].value_counts()
# Out:
# ram_gb
# 8 GB     418
# 4 GB     226
# 16 GB    177
# 32 GB      2
# Name: count, dtype: int64

# %%
dt = {"8 GB":8,"4 GB":4,"16 GB":16,"32 GB":32}
dt
# Out:
# {'8 GB': 8, '4 GB': 4, '16 GB': 16, '32 GB': 32}

# %%
df['ram_gb'] = df['ram_gb'].map(dt)

# %%
df['ram_gb']
# Out:
# 0      4
# 1      4
# 2      4
# 3      8
# 4      4
#       ..
# 818    4
# 819    4
# 820    4
# 821    4
# 822    8
# Name: ram_gb, Length: 823, dtype: int64

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn  ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th       4     DDR4
# 1    Lenovo           Intel        Core i3            10th       4     DDR4
# 2    Lenovo           Intel        Core i3            10th       4     DDR4
# 3      ASUS           Intel        Core i5            10th       8     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available       4     DDR4
# ..      ...             ...            ...             ...     ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available       4     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available       4     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available       4     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available       4     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th       8     DDR4
#
# ...
